# %% [markdown]
# <a href="https://colab.research.google.com/github/sairaawahid/Data-Science-in-Python-Data-Prep-and-EDA/blob/main/Data%20Visualization/Visualizing_data_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignments: Visualizing Data
#
# **Datasets:**
# 1.  spotify_songs.csv

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# Hi,
#
# Our music analysis team has labeled 100 songs with their musical attributes, such as its danceability and energy. Can you tell us more about the distributions of the musical attributes? I’m guessing that since most of the musical attributes are numeric, they should be normally distributed, but let me know if you see otherwise.
#
# Thanks!\
# Sarah
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Read in the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

songs = pd.read_csv('/content/drive/MyDrive/Data Science in Pyhton by Maven Analytics/1. Data Prep & EDA/Data/spotify_songs.csv')
songs.head()
# Out:
#                            name       artists  energy  key  mode  valence  \
# 0                    God's Plan         Drake   0.449    7     1    0.357
# 1                          SAD!  XXXTENTACION   0.613    8     1    0.473
# 2    rockstar (feat. 21 Savage)   Post Malone   0.535    5     0    0.140
# 3  Psycho (feat. Ty Dolla $ign)   Post Malone   0.559    8     1    0.439
# 4                In My Feelings         Drake   0.626    1     1    0.350
#
#      tempo  duration_ms
# 0   77.169       198973
# 1   75.023       166606
# 2  159.847       218147
# 3  140.124       221440
# 4   91.030       217925

# %%
songs.shape
# Out:
# (100, 8)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Distributions

# %% [markdown]
# ### Interpret the histograms
#
# [Musical attribute definitions](https://developer.spotify.com/documentation/web-api/reference/get-audio-features)
#
# * **Fields with normal distributions:** valence
# * **Fields with other distributions:** key and mode
# * **Skewed fields:** energy
# * **Outliers:** duration_ms
# * **Other observations:** tempos of 90-100 are really popular
# * **Do your interpretations make sense?**

# %%
# Import the seaborn library
import seaborn as sns

# %%
# Create a pair plot
sns.pairplot(songs);

# %%
# Duration outliers
songs[songs.duration_ms > 300000]
# Out:
#                name       artists  energy  key  mode  valence    tempo  \
# 21  Te Bot? - Remix    Nio Garcia   0.675   11     0    0.442   96.507
# 42       SICKO MODE  Travis Scott   0.730    8     1    0.446  155.008
#
#     duration_ms
# 21       417920
# 42       312820

# %%
# tempo histogram
sns.histplot(songs.tempo);

# %%
# tempo histogram with more bins
sns.histplot(songs.tempo, bins=10);

# %%
# Look at the tempo of most songs
songs.tempo.round(-1).value_counts().sort_index()
# Out:
# tempo
# 60.0      1
# 80.0      5
# 90.0     16
# 100.0    19
# 110.0     6
# 120.0    12
# 130.0    12
# 140.0    10
# 150.0     7
# 160.0     3
# 170.0     3
# 180.0     4
# 190.0     1
# 200.0     1
# Name: count, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Correlations

# %% [markdown]
# Hi again,
#
# Thanks for looking into those distributions earlier. Can you also tell us more about the correlations of the musical attributes?
# Can you tell us about any relationships you can find in the data between the attributes, like if some are positively or negatively correlated?
#
# Thanks!\
# Sarah

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### Interpret the scatter plots
#
# [Musical attribute definitions](https://developer.spotify.com/documentation/web-api/reference/get-audio-features)
#
# * **Highly correlated:** None
# * **Uncorrelated:** key vs valence / tempo / duration_ms
# * **Positive correlation:** energy vs valence
# * Negative correlation: mode vs valence
# * Other observations: key and mode are discrete, duration_ms has an outlier
# * Do your interpretations make sense?

# %%
songs.corr(method='pearson', numeric_only=True)
# Out:
#                energy       key      mode   valence     tempo  duration_ms
# energy       1.000000 -0.136345 -0.117555  0.382434  0.062272     0.073017
# key         -0.136345  1.000000 -0.141568 -0.032622  0.003737     0.046144
# mode        -0.117555 -0.141568  1.000000 -0.210599 -0.011911     0.055411
# valence      0.382434 -0.032622 -0.210599  1.000000 -0.148423    -0.131901
# tempo        0.062272  0.003737 -0.011911 -0.148423  1.000000     0.005493
# duration_ms  0.073017  0.046144  0.055411 -0.131901  0.005493     1.000000

# %%
sns.pairplot(songs);

# %%
songs.sort_values(by='valence', ascending=False)
# Out:
#                                        name        artists  energy  key  mode  \
# 25                             Shape of You     Ed Sheeran   0.652    1     0
# 46          Finesse (Remix) [feat. Cardi B]     Bruno Mars   0.859    5     0
# 89                                    Bella        Wolfine   0.493    3     1
# 78                                 Criminal  Natti Natasha   0.813    2     0
# 66  D?jala que vuelva (feat. Manuel Turizo)        Piso 21   0.788    1     1
# ..                                      ...            ...     ...  ...   ...
# 2                rockstar (feat. 21 Savage)    Post Malone   0.535    5     0
# 80                     lovely (with Khalid)  Billie Eilish   0.296    4     0
# 93                               This Is Me   Keala Settle   0.704    2     1
# 98              Dusk Till Dawn - Radio Edit           ZAYN   0.437   11     0
# 33                                Nevermind   Dennis Lloyd   0.691    3     1
#
#     valence    tempo  duration_ms
# 25   0.9310   95.977       233713
# 46   0.9260  105.115       217289
# 89   0.8440   94.016       197120
# 78   0.8390   79.997       232550
# 66   0.8390  170.019       220117
# ..      ...      ...          ...
# 2    0.1400  159.847       218147
# 80   0.1200  115.284       200186
# 93   0.1000  191.702       234707
# 98   0.0967  180.043       239000
# 33   0.0796   99.976       156600
#
# [100 rows x 8 columns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
